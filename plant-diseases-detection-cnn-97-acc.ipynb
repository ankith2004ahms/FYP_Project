# %% [markdown]
# # **Import Libraries:**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,Dropout,MaxPooling2D,Flatten
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2025-10-03 14:03:05.948483: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759500186.182472      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759500186.244841      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Read Training Data

# %%
train_data=ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

# %%
train_generator=train_data.flow_from_directory(
    '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/',
    target_size=(150, 150),
    batch_size=128,
    class_mode='categorical',
    subset='training'  
    
)
# Out:
# Found 56251 images belonging to 38 classes.

# %% [markdown]
# ## Read Validation Data

# %%
validation_generator = train_data.flow_from_directory(
    '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/',
    target_size=(150, 150),
    batch_size=128,
    class_mode='categorical',
    subset='validation'  
)
# Out:
# Found 14044 images belonging to 38 classes.

# %% [markdown]
# ## Read Test Data

# %%
test_data=ImageDataGenerator(
    rescale=1./255
)

# %%
test_generator=test_data.flow_from_directory(
    '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/',
    target_size=(150, 150),
    batch_size=128,
    class_mode='categorical'
    
)
# Out:
# Found 17572 images belonging to 38 classes.

# %% [markdown]
# # **Showing Each Class Name and Coressponding Index:**

# %%
# Display the 38 unique class names (labels) each one in seperated line 
for label,index in train_generator.class_indices.items():
    print(index," : ",label)
# Out:
# 0  :  Apple___Apple_scab
# 1  :  Apple___Black_rot
# 2  :  Apple___Cedar_apple_rust
# 3  :  Apple___healthy
# 4  :  Blueberry___healthy
# 5  :  Cherry_(including_sour)___Powdery_mildew
# 6  :  Cherry_(including_sour)___healthy
# 7  :  Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# 8  :  Corn_(maize)___Common_rust_
# 9  :  Corn_(maize)___Northern_Leaf_Blight
# 10  :  Corn_(maize)___healthy
# 11  :  Grape___Black_rot
# 12  :  Grape___Esca_(Black_Measles)
# 13  :  Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14  :  Grape___healthy
# 15  :  Orange___Haunglongbing_(Citrus_greening)
# 16  :  Peach___Bacterial_spot
# 17  :  Peach___healthy
# 18  :  Pepper,_bell___Bacterial_spot
# 19  :  Pepper,_bell___healthy
# 20  :  Potato___Early_blight
# 21  :  Potato___Late_blight
# 22  :  Potato___healthy
# 23  :  Raspberry___healthy
# 24  :  Soybean___healthy
# 25  :  Squash___Powdery_mildew
# 26  :  Strawberry___Leaf_scorch
# 27  :  Strawberry___healthy
# 28  :  Tomato___Bacterial_spot
# 29  :  Tomato___Early_blight
# 30  :  Tomato___Late_blight
# 31  :  Tomato___Leaf_Mold
# 32  :  Tomato___Septoria_leaf_spot
# 33  :  Tomato___Spider_mites Two-spotted_spider_mite
# 34  :  Tomato___Target_Spot
# 35  :  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36  :  Tomato___Tomato_mosaic_virus
# 37  :  Tomato___healthy

# %%
images, labels = next(train_generator) 

class_labels = {v: k for k, v in train_generator.class_indices.items()}

label_indices = np.argmax(labels, axis=1)

random_indices = np.random.choice(len(images), 50, replace=False)  

plt.figure(figsize=(20, 20))
for i, idx in enumerate(random_indices):
    plt.subplot(10, 5, i + 1)  
    plt.imshow(images[idx])
    plt.title(class_labels[label_indices[idx]])  
    plt.axis('off')  
plt.show()

# %% [markdown]
# # **CNN Model:**

# %%
model=Sequential([
  # Input Layer in CNN 
  Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)),



  # Feture Extraction Layers in CNN with MaxPooling 
  Conv2D(32,(3,3),activation='relu'),
  MaxPooling2D((2,2)),
  Conv2D(64,(3,3),activation='relu'),
  MaxPooling2D((2,2)),
  Conv2D(128,(3,3),activation='relu'),
  MaxPooling2D((2,2)),
  Conv2D(256,(3,3),activation='relu'),
  MaxPooling2D((2,2)),
  Conv2D(512,(3,3),activation='relu'),
  MaxPooling2D((2,2)),
  
    
# Fully Connected Neural Network
  Flatten(),
  Dense(512, activation='relu'),
  Dropout(0.5),
  Dense(38, activation='softmax')  
  
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1759500225.435573      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 146, 146, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 73, 73, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 71, 71, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 35, 35, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 33, 33, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 5, 5, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 38)             │        19,494 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,646,406 (10.10 MB)
#  Trainable params: 2,646,406 (10.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **Fitting the CNN Model:**

# %%
from tensorflow.keras import metrics
model.compile(optimizer='adam',loss='categorical_crossentropy'
              ,metrics=['accuracy',metrics.Recall(),metrics.Precision()])

# %%
early_stopping=EarlyStopping(monitor='val_loss',patience=5)
model_checkpoint=ModelCheckpoint(
    'best_model.keras',  
    monitor='val_loss',  
    save_best_only=True,  
    mode='min',  
    verbose=1  
)

# %%
history=model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=50,
    callbacks=[early_stopping,model_checkpoint],
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759500235.376638      83 service.cc:148] XLA service 0x7a9764215490 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759500235.377946      83 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759500235.908974      83 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-10-03 14:04:03.385755: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,32,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,148,148]{3,2,1,0}, f32[128,32,146,146]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-10-03 14:04:03.459150: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.07351482s
# Trying algorithm eng0{} for conv (f32[32,32,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,32,148,148]{3,2,1,0}, f32[128,32,146,146]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
#   2/439 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.0488 - loss: 3.6327 - precision: 0.0000e+00 - recall: 0.0000e+00
# I0000 00:00:1759500246.548354      83 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1252 - loss: 3.1606 - precision: 0.4984 - recall: 0.0328
# Epoch 1: val_loss improved from inf to 1.31931, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 727s 2s/step - accuracy: 0.1256 - loss: 3.1592 - precision: 0.4988 - recall: 0.0330 - val_accuracy: 0.5925 - val_loss: 1.3193 - val_precision: 0.7886 - val_recall: 0.4192
# Epoch 2/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 38s 89ms/step - accuracy: 0.6641 - loss: 1.1726 - precision: 0.8219 - recall: 0.4688
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_loss did not improve from 1.31931
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 81s 185ms/step - accuracy: 0.6641 - loss: 1.1726 - precision: 0.8219 - recall: 0.4688 - val_accuracy: 0.5821 - val_loss: 1.3415 - val_precision: 0.7707 - val_recall: 0.4161
# Epoch 3/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - accuracy: 0.6232 - loss: 1.2068 - precision: 0.7759 - recall: 0.4830
# Epoch 3: val_loss improved from 1.31931 to 0.65647, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 436s 993ms/step - accuracy: 0.6233 - loss: 1.2063 - precision: 0.7760 - recall: 0.4832 - val_accuracy: 0.7911 - val_loss: 0.6565 - val_precision: 0.8571 - val_recall: 0.7345
# Epoch 4/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 38s 88ms/step - accuracy: 0.7188 - loss: 0.8918 - precision: 0.7810 - recall: 0.6406
# Epoch 4: val_loss did not improve from 0.65647
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 84s 192ms/step - accuracy: 0.7188 - loss: 0.8918 - precision: 0.7810 - recall: 0.6406 - val_accuracy: 0.7852 - val_loss: 0.6738 - val_precision: 0.8520 - val_recall: 0.7256
# Epoch 5/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.7980 - loss: 0.6298 - precision: 0.8646 - recall: 0.7397
# Epoch 5: val_loss improved from 0.65647 to 0.41375, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 421s 959ms/step - accuracy: 0.7980 - loss: 0.6297 - precision: 0.8646 - recall: 0.7398 - val_accuracy: 0.8643 - val_loss: 0.4138 - val_precision: 0.9083 - val_recall: 0.8240
# Epoch 6/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 38s 88ms/step - accuracy: 0.8594 - loss: 0.4771 - precision: 0.8818 - recall: 0.7578
# Epoch 6: val_loss improved from 0.41375 to 0.39312, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 84s 191ms/step - accuracy: 0.8594 - loss: 0.4771 - precision: 0.8818 - recall: 0.7578 - val_accuracy: 0.8725 - val_loss: 0.3931 - val_precision: 0.9120 - val_recall: 0.8329
# Epoch 7/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 767ms/step - accuracy: 0.8557 - loss: 0.4492 - precision: 0.8943 - recall: 0.8206
# Epoch 7: val_loss improved from 0.39312 to 0.30078, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 419s 955ms/step - accuracy: 0.8557 - loss: 0.4492 - precision: 0.8943 - recall: 0.8207 - val_accuracy: 0.8999 - val_loss: 0.3008 - val_precision: 0.9264 - val_recall: 0.8764
# Epoch 8/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.8203 - loss: 0.5801 - precision: 0.8696 - recall: 0.7812
# Epoch 8: val_loss did not improve from 0.30078
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 81s 185ms/step - accuracy: 0.8203 - loss: 0.5801 - precision: 0.8696 - recall: 0.7812 - val_accuracy: 0.8900 - val_loss: 0.3287 - val_precision: 0.9181 - val_recall: 0.8650
# Epoch 9/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.8850 - loss: 0.3540 - precision: 0.9138 - recall: 0.8602
# Epoch 9: val_loss improved from 0.30078 to 0.29251, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 425s 969ms/step - accuracy: 0.8850 - loss: 0.3540 - precision: 0.9138 - recall: 0.8602 - val_accuracy: 0.9062 - val_loss: 0.2925 - val_precision: 0.9257 - val_recall: 0.8871
# Epoch 10/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.9219 - loss: 0.2117 - precision: 0.9417 - recall: 0.8828
# Epoch 10: val_loss improved from 0.29251 to 0.27260, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 83s 189ms/step - accuracy: 0.9219 - loss: 0.2117 - precision: 0.9417 - recall: 0.8828 - val_accuracy: 0.9108 - val_loss: 0.2726 - val_precision: 0.9323 - val_recall: 0.8946
# Epoch 11/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9061 - loss: 0.2862 - precision: 0.9269 - recall: 0.8878
# Epoch 11: val_loss improved from 0.27260 to 0.21940, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 439s 1000ms/step - accuracy: 0.9062 - loss: 0.2861 - precision: 0.9269 - recall: 0.8878 - val_accuracy: 0.9231 - val_loss: 0.2194 - val_precision: 0.9363 - val_recall: 0.9148
# Epoch 12/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 39s 90ms/step - accuracy: 0.9375 - loss: 0.1549 - precision: 0.9444 - recall: 0.9297
# Epoch 12: val_loss did not improve from 0.21940
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 81s 186ms/step - accuracy: 0.9375 - loss: 0.1549 - precision: 0.9444 - recall: 0.9297 - val_accuracy: 0.9121 - val_loss: 0.2600 - val_precision: 0.9245 - val_recall: 0.8999
# Epoch 13/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.9190 - loss: 0.2445 - precision: 0.9343 - recall: 0.9048
# Epoch 13: val_loss improved from 0.21940 to 0.20413, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 432s 984ms/step - accuracy: 0.9190 - loss: 0.2445 - precision: 0.9343 - recall: 0.9048 - val_accuracy: 0.9318 - val_loss: 0.2041 - val_precision: 0.9455 - val_recall: 0.9219
# Epoch 14/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.9609 - loss: 0.1296 - precision: 0.9762 - recall: 0.9609
# Epoch 14: val_loss did not improve from 0.20413
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 82s 187ms/step - accuracy: 0.9609 - loss: 0.1296 - precision: 0.9762 - recall: 0.9609 - val_accuracy: 0.9284 - val_loss: 0.2132 - val_precision: 0.9422 - val_recall: 0.9168
# Epoch 15/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.9311 - loss: 0.2084 - precision: 0.9457 - recall: 0.9196
# Epoch 15: val_loss did not improve from 0.20413
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 409s 933ms/step - accuracy: 0.9311 - loss: 0.2084 - precision: 0.9457 - recall: 0.9196 - val_accuracy: 0.9270 - val_loss: 0.2221 - val_precision: 0.9387 - val_recall: 0.9160
# Epoch 16/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 37s 86ms/step - accuracy: 0.9219 - loss: 0.1818 - precision: 0.9512 - recall: 0.9141
# Epoch 16: val_loss did not improve from 0.20413
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 81s 184ms/step - accuracy: 0.9219 - loss: 0.1818 - precision: 0.9512 - recall: 0.9141 - val_accuracy: 0.9273 - val_loss: 0.2233 - val_precision: 0.9387 - val_recall: 0.9180
# Epoch 17/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.9360 - loss: 0.1940 - precision: 0.9468 - recall: 0.9255
# Epoch 17: val_loss improved from 0.20413 to 0.18355, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 413s 941ms/step - accuracy: 0.9360 - loss: 0.1940 - precision: 0.9468 - recall: 0.9255 - val_accuracy: 0.9409 - val_loss: 0.1835 - val_precision: 0.9507 - val_recall: 0.9323
# Epoch 18/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 39s 89ms/step - accuracy: 0.9688 - loss: 0.1210 - precision: 0.9764 - recall: 0.9688
# Epoch 18: val_loss improved from 0.18355 to 0.17582, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 81s 184ms/step - accuracy: 0.9688 - loss: 0.1210 - precision: 0.9764 - recall: 0.9688 - val_accuracy: 0.9428 - val_loss: 0.1758 - val_precision: 0.9537 - val_recall: 0.9339
# Epoch 19/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.9398 - loss: 0.1808 - precision: 0.9494 - recall: 0.9313
# Epoch 19: val_loss did not improve from 0.17582
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 408s 929ms/step - accuracy: 0.9398 - loss: 0.1808 - precision: 0.9494 - recall: 0.9313 - val_accuracy: 0.9390 - val_loss: 0.1866 - val_precision: 0.9470 - val_recall: 0.9315
# Epoch 20/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 37s 86ms/step - accuracy: 0.9297 - loss: 0.1510 - precision: 0.9516 - recall: 0.9219
# Epoch 20: val_loss did not improve from 0.17582
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 83s 188ms/step - accuracy: 0.9297 - loss: 0.1510 - precision: 0.9516 - recall: 0.9219 - val_accuracy: 0.9346 - val_loss: 0.1988 - val_precision: 0.9444 - val_recall: 0.9272
# Epoch 21/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 763ms/step - accuracy: 0.9452 - loss: 0.1638 - precision: 0.9537 - recall: 0.9377
# Epoch 21: val_loss did not improve from 0.17582
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 418s 951ms/step - accuracy: 0.9452 - loss: 0.1638 - precision: 0.9537 - recall: 0.9377 - val_accuracy: 0.9418 - val_loss: 0.1771 - val_precision: 0.9506 - val_recall: 0.9356
# Epoch 22/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 39s 89ms/step - accuracy: 0.9609 - loss: 0.1104 - precision: 0.9677 - recall: 0.9375
# Epoch 22: val_loss improved from 0.17582 to 0.17095, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 83s 190ms/step - accuracy: 0.9609 - loss: 0.1104 - precision: 0.9677 - recall: 0.9375 - val_accuracy: 0.9407 - val_loss: 0.1710 - val_precision: 0.9492 - val_recall: 0.9348
# Epoch 23/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - accuracy: 0.9521 - loss: 0.1474 - precision: 0.9598 - recall: 0.9443
# Epoch 23: val_loss did not improve from 0.17095
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 416s 948ms/step - accuracy: 0.9521 - loss: 0.1474 - precision: 0.9598 - recall: 0.9443 - val_accuracy: 0.9374 - val_loss: 0.1987 - val_precision: 0.9456 - val_recall: 0.9302
# Epoch 24/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 18s 42ms/step - accuracy: 0.9661 - loss: 0.2177 - precision: 0.9661 - recall: 0.9661
# Epoch 24: val_loss did not improve from 0.17095
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 80s 183ms/step - accuracy: 0.9661 - loss: 0.2177 - precision: 0.9661 - recall: 0.9661 - val_accuracy: 0.9409 - val_loss: 0.1870 - val_precision: 0.9485 - val_recall: 0.9342
# Epoch 25/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9551 - loss: 0.1412 - precision: 0.9613 - recall: 0.9494
# Epoch 25: val_loss improved from 0.17095 to 0.16952, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 438s 997ms/step - accuracy: 0.9551 - loss: 0.1412 - precision: 0.9613 - recall: 0.9494 - val_accuracy: 0.9460 - val_loss: 0.1695 - val_precision: 0.9538 - val_recall: 0.9401
# Epoch 26/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 37s 86ms/step - accuracy: 0.9453 - loss: 0.1667 - precision: 0.9528 - recall: 0.9453
# Epoch 26: val_loss improved from 0.16952 to 0.15541, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 82s 188ms/step - accuracy: 0.9453 - loss: 0.1667 - precision: 0.9528 - recall: 0.9453 - val_accuracy: 0.9515 - val_loss: 0.1554 - val_precision: 0.9582 - val_recall: 0.9458
# Epoch 27/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9555 - loss: 0.1336 - precision: 0.9622 - recall: 0.9491
# Epoch 27: val_loss improved from 0.15541 to 0.13040, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 434s 988ms/step - accuracy: 0.9555 - loss: 0.1336 - precision: 0.9622 - recall: 0.9491 - val_accuracy: 0.9584 - val_loss: 0.1304 - val_precision: 0.9639 - val_recall: 0.9554
# Epoch 28/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 37s 86ms/step - accuracy: 0.9766 - loss: 0.0674 - precision: 0.9766 - recall: 0.9766
# Epoch 28: val_loss improved from 0.13040 to 0.12911, saving model to best_model.keras
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 80s 182ms/step - accuracy: 0.9766 - loss: 0.0674 - precision: 0.9766 - recall: 0.9766 - val_accuracy: 0.9577 - val_loss: 0.1291 - val_precision: 0.9636 - val_recall: 0.9542
# Epoch 29/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - accuracy: 0.9621 - loss: 0.1183 - precision: 0.9685 - recall: 0.9571
# Epoch 29: val_loss did not improve from 0.12911
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 407s 927ms/step - accuracy: 0.9621 - loss: 0.1183 - precision: 0.9685 - recall: 0.9570 - val_accuracy: 0.9565 - val_loss: 0.1385 - val_precision: 0.9624 - val_recall: 0.9513
# Epoch 30/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.9688 - loss: 0.1069 - precision: 0.9688 - recall: 0.9688
# Epoch 30: val_loss did not improve from 0.12911
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 80s 182ms/step - accuracy: 0.9688 - loss: 0.1069 - precision: 0.9688 - recall: 0.9688 - val_accuracy: 0.9488 - val_loss: 0.1644 - val_precision: 0.9567 - val_recall: 0.9442
# Epoch 31/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9615 - loss: 0.1186 - precision: 0.9663 - recall: 0.9562
# Epoch 31: val_loss did not improve from 0.12911
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 419s 954ms/step - accuracy: 0.9615 - loss: 0.1186 - precision: 0.9662 - recall: 0.9562 - val_accuracy: 0.9476 - val_loss: 0.1625 - val_precision: 0.9545 - val_recall: 0.9429
# Epoch 32/50
#   1/439 ━━━━━━━━━━━━━━━━━━━━ 38s 88ms/step - accuracy: 0.9609 - loss: 0.1581 - precision: 0.9680 - recall: 0.9453
# Epoch 32: val_loss did not improve from 0.12911
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 79s 180ms/step - accuracy: 0.9609 - loss: 0.1581 - precision: 0.9680 - recall: 0.9453 - val_accuracy: 0.9498 - val_loss: 0.1549 - val_precision: 0.9554 - val_recall: 0.9450
# Epoch 33/50
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - accuracy: 0.9649 - loss: 0.1058 - precision: 0.9702 - recall: 0.9608
# Epoch 33: val_loss did not improve from 0.12911
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 425s 967ms/step - accuracy: 0.9649 - loss: 0.1058 - precision: 0.9702 - recall: 0.9608 - val_accuracy: 0.9482 - val_loss: 0.1692 - val_precision: 0.9546 - val_recall: 0.9439

# %% [markdown]
# # **Showing Training and Validation Accuracy of Best Model after Finishing Training Epochs**

# %%
# using max to use best model saved by modelcheckpoint
train_accuracy = max(history.history['accuracy'])
val_accuracy = max(history.history['val_accuracy']) 

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Training Accuracy: 0.9766
# Validation Accuracy: 0.9584

# %% [markdown]
# # **Model Evaluation:**

# %%
results = model.evaluate(test_generator)
loss = results[0]
accuracy = results[1]
precision = results[2]
recall = results[3]

print(f'Testing Loss: {loss}')
print(f'Testing Accuracy: {accuracy}')
print(f'Testing Precision: {precision}')
print(f'Testing Recall: {recall}')
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 129s 932ms/step - accuracy: 0.9556 - loss: 0.1446 - precision: 0.9629 - recall: 0.9509
# Testing Loss: 0.14624230563640594
# Testing Accuracy: 0.954757571220398
# Testing Precision: 0.9503186941146851
# Testing Recall: 0.9609829187393188

# %%
# Get predictions on the validation set
y_probs = model.predict(validation_generator)   
y_pred = np.argmax(y_probs, axis=1)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 82s 741ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Get predictions
y_probs = model.predict(validation_generator)   
y_pred = np.argmax(y_probs, axis=1)             
y_true = validation_generator.classes           

# Step 2: Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
labels = list(validation_generator.class_indices.keys())

plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# Step 3: Classification Report
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=labels))
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 81s 732ms/step
# Classification Report:
#
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.03      0.03      0.03       403
#                                  Apple___Black_rot       0.05      0.05      0.05       397
#                           Apple___Cedar_apple_rust       0.02      0.02      0.02       352
#                                    Apple___healthy       0.02      0.02      0.02       401
#                                Blueberry___healthy       0.03      0.03      0.03       363
#           Cherry_(including_sour)___Powdery_mildew       0.03      0.03      0.03       336
#                  Cherry_(including_sour)___healthy       0.03      0.03      0.03       365
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.02      0.02      0.02       328
#                        Corn_(maize)___Common_rust_       0.03      0.03      0.03       381
#                Corn_(maize)___Northern_Leaf_Blight       0.03      0.03      0.03       381
#                             Corn_(maize)___healthy       0.04      0.04      0.04       371
#                                  Grape___Black_rot       0.02      0.02      0.02       377
#                       Grape___Esca_(Black_Measles)       0.03      0.03      0.03       384
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.02      0.02      0.02       344
#                                    Grape___healthy       0.03      0.03      0.03       338
#           Orange___Haunglongbing_(Citrus_greening)       0.03      0.03      0.03       402
#                             Peach___Bacterial_spot       0.01      0.01      0.01       367
#                                    Peach___healthy       0.03      0.03      0.03       345
#                      Pepper,_bell___Bacterial_spot       0.03      0.03      0.03       382
#                             Pepper,_bell___healthy       0.03      0.03      0.03       397
#                              Potato___Early_blight       0.01      0.01      0.01       387
#                               Potato___Late_blight       0.03      0.03      0.03       387
#                                   Potato___healthy       0.02      0.01      0.01       364
#                                Raspberry___healthy       0.02      0.03      0.02       356
#                                  Soybean___healthy       0.03      0.03      0.03       404
#                            Squash___Powdery_mildew       0.03      0.03      0.03       347
#                           Strawberry___Leaf_scorch       0.03      0.03      0.03       354
#                               Strawberry___healthy       0.03      0.03      0.03       364
#                            Tomato___Bacterial_spot       0.01      0.01      0.01       340
#                              Tomato___Early_blight       0.02      0.02      0.02       384
#                               Tomato___Late_blight       0.02      0.02      0.02       370
#                                 Tomato___Leaf_Mold       0.02      0.02      0.02       376
#                        Tomato___Septoria_leaf_spot       0.03      0.03      0.03       349
#      Tomato___Spider_mites Two-spotted_spider_mite       0.02      0.02      0.02       348
#                               Tomato___Target_Spot       0.03      0.03      0.03       365
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.04      0.05      0.04       392
#                       Tomato___Tomato_mosaic_virus       0.04      0.04      0.04       358
#                                   Tomato___healthy       0.02      0.02      0.02       385
#
#                                           accuracy                           0.03     14044
#                                          macro avg       0.03      0.03      0.03     14044
#                                       weighted avg       0.03      0.03      0.03     14044

# %% [markdown]
# # **Save the Model:**

# %%
model.save('/kaggle/working/my_cnn_model.h5')
